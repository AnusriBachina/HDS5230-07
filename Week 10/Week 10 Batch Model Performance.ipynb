# %% [markdown]
# Week 10
#
# Anusri Bachina

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load all datasets
df1 = pd.read_csv("first.csv")
df2 = pd.read_csv("second.csv")
df3 = pd.read_csv("third.csv")
df4 = pd.read_csv("fourth.csv")

# %%
# Define the steps in the batch model
steps = ['Dummy', 'KNN-1', 'KNN-2', 'KNN-3-1', 'KNN-3-2']

# Metrics for each step based on the notebook's result_scores structure
# Format: step -> (accuracy, recall, precision)
performance = {
    'Dummy': (0.4575, 0.4663, 0.4778),
    'KNN Training': (0.8825, 0.875, 0.8966),
    'KNN Prediction': (0.965, 0.9412, 0.91),
    'KNN-3-1': (0.701, 0.3996, 1.0),
    'KNN-3-2': (0.9575, 0.8571, 0.9)
}

# %%
# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(models, accuracy, marker='o', label='Accuracy', linewidth=2)
plt.plot(models, recall, marker='s', label='Recall', linewidth=2)
plt.plot(models, precision, marker='^', label='Precision', linewidth=2)

# Graph style
plt.title("Batch Model Performance: Accuracy, Recall, Precision over Steps", fontsize=14)
plt.xlabel("Model Steps", fontsize=12)
plt.ylabel("Performance Metrics", fontsize=12)
plt.ylim(0.3, 1.05)
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display the plot
plt.show()
